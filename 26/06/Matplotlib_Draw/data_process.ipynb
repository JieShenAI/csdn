# %% [markdown]
# 为减少占用空间，不提供原始数据

# %%
import pandas as pd

# %%
df = pd.read_excel('data/图像详细信息.xlsx')

# %%
df.columns
# Out:
# Index(['序号', '文件名', '卫星', '站名', '工作模式', '轨道号', '景中心经度(°)', '景中心纬度(°)',
#        '数据获取日期', '产品级别', '极化方式', '数据来源'],
#       dtype='object')

# %%
df.shape
# Out:
# (137587, 12)

# %%
df.head(3)
# Out:
#    序号                                                文件名   卫星   站名  工作模式  \
# 0   1  CS1_KSC_QPSI_007200_E97.0_N12.5_20230406_L1A_A...  CS1  KSC  QPSI
# 1   2  CS1_KSC_QPSI_007200_E97.0_N12.7_20230406_L1A_A...  CS1  KSC  QPSI
# 2   3  CS1_KSC_QPSI_007200_E97.1_N12.2_20230406_L1A_A...  CS1  KSC  QPSI
#
#     轨道号  景中心经度(°)  景中心纬度(°)    数据获取日期 产品级别 极化方式   数据来源
# 0  7200      97.0      12.5  20230406  L1A  AHV  train
# 1  7200      97.0      12.7  20230406  L1A  AHV  train
# 2  7200      97.1      12.2  20230406  L1A  AHV  train

# %%
new_df = df[['景中心经度(°)', '景中心纬度(°)']]

# %%
new_df.shape
# Out:
# (137587, 2)

# %%
new_df.to_csv("data/经纬度数据.csv", index=False)

# %%
df.columns[6:8]
# Out:
# Index(['景中心经度(°)', '景中心纬度(°)'], dtype='object')
